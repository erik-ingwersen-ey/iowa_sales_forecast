# %%
import pandas as pd

from google.cloud import bigquery
from google.cloud.bigquery import Client

# %%
PROJECT_ID = "bunge-demo"

START_DATE = "2021-01-01"
END_DATE = "2024-01-01"

OFFSET_START_DATE = (pd.Timestamp(START_DATE) - pd.DateOffset(days=61)).strftime("%Y-%m-%d")

# %%
client = bigquery.Client(PROJECT_ID)

# %%
query = """
SELECT 
    *
FROM
  `bigquery-public-data.iowa_liquor_sales.sales` 
LIMIT 
  5
"""
query_job = client.query(query)
df = query_job.to_dataframe()
df
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722826245.795942  901739 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#   invoice_and_item_number        date store_number  \
# 0        RINV-04311100003  2022-10-10         6151
# 1        RINV-04712400129  2023-06-26         3390
# 2        RINV-04963200033  2023-11-17         5157
# 3        RINV-04536000097  2023-03-03         5916
# 4        RINV-04777300067  2023-08-01         5257
#
#                         store_name                       address  \
# 0         UNIVERSITY LIQUORS / WDM  9250 UNIVERSITY AVE UNIT 115
# 1            OKOBOJI AVENUE LIQUOR           1610 OKOBOJI AVENUE
# 2  KIMMES MANSON COUNTRY STORE #10                   208 MAIN ST
# 3           ANOTHER ROUND / DEWITT                 622 S 6TH AVE
# 4                MAD AVE QUIK SHOP              405, MADISON AVE
#
#               city zip_code                     store_location county_number  \
# 0  WEST DES MOINES    50266        POINT(-93.834244 41.599769)          None
# 1          MILFORD  51351.0   POINT(-95.149544969 43.33153601)          None
# 2           MANSON  50563.0  POINT(-94.535010985 42.517901986)          None
# 3           DEWITT  52742.0          POINT(-90.53908 41.80942)          None
# 4          OTTUMWA  52501.0  POINT(-92.410605275 40.999140319)          None
#
#       county  ... item_number         item_description pack bottle_volume_ml  \
# 0       POLK  ...      948167            HENNESSY VSOP    6             1750
# 1  DICKINSON  ...       19477              MAKERS MARK   12             1000
# 2    CALHOUN  ...       41694        UV BLUE RASPBERRY   12             1000
# 3    CLINTON  ...       42717           MALIBU COCONUT   12             1000
# 4    WAPELLO  ...       69637  DR MCGILLICUDDYS CHERRY   12             1000
#
#   state_bottle_cost state_bottle_retail  bottles_sold  sale_dollars  \
# 0             59.99               89.99           -18      -1619.82
# 1             22.50               33.75           -12       -405.00
# 2              7.50               11.25           -12       -135.00
# 3             11.99               17.99           -12       -215.88
# 4             11.00               16.50           -12       -198.00
#
#    volume_sold_liters  volume_sold_gallons
# 0               -31.5                -8.32
# 1               -12.0                -3.17
# 2               -12.0                -3.17
# 3               -12.0                -3.17
# 4               -12.0                -3.17
#
# [5 rows x 24 columns]

# %%
query = f"""
WITH sales_data AS (
    SELECT 
        city,
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold,
        AVG(state_bottle_retail) AS avg_bottle_price,
        SUM(volume_sold_liters) AS total_volume_sold_liters,
        SUM(sale_dollars) AS total_sale_dollars,
        AVG(state_bottle_retail - state_bottle_cost) AS avg_bottle_profit
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales`
    WHERE
        bottles_sold > 0
        AND sale_dollars > 0
    GROUP BY
        city, date, item_name
    HAVING
        date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
)

SELECT
    city,
    date,
    item_name,
    total_amount_sold,
    avg_bottle_price,
    total_volume_sold_liters,
    total_sale_dollars,
    avg_bottle_profit,
    -- 7-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_sale_dollars,
    -- 30-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_sale_dollars
FROM
    sales_data
ORDER BY
    city, date, item_name;
"""

query_job = client.query(query)
df = query_job.to_dataframe()
df
# Out:
# I0000 00:00:1722826718.633829  901739 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#             city        date                       item_name  \
# 0           None  2023-01-23                    BLACK VELVET
# 1           None  2023-01-23                BLANTONS BOURBON
# 2           None  2023-01-23  CAPTAIN MORGAN ORIGINAL SPICED
# 3           None  2023-01-23                     CROWN ROYAL
# 4           None  2023-01-23                CROWN ROYAL MINI
# ...          ...         ...                             ...
# 1708740  ZWINGLE  2023-12-11             PARAMOUNT WHITE RUM
# 1708741  ZWINGLE  2023-12-11                 PATRON REPOSADO
# 1708742  ZWINGLE  2023-12-11           PATRON REPOSADO 200ML
# 1708743  ZWINGLE  2023-12-11                SOUTHERN COMFORT
# 1708744  ZWINGLE  2023-12-11               UV BLUE RASPBERRY
#
#          total_amount_sold  avg_bottle_price  total_volume_sold_liters  \
# 0                       18            11.765                      19.5
# 1                        6            43.130                       4.5
# 2                       12            13.590                       9.0
# 3                       24            12.740                       9.0
# 4                       10            14.930                       0.5
# ...                    ...               ...                       ...
# 1708740                  6            12.000                      10.5
# 1708741                  2            43.500                       1.5
# 1708742                  2            15.330                       0.4
# 1708743                 48             3.960                       9.6
# 1708744                 24             5.240                       9.0
#
#          total_sale_dollars  avg_bottle_profit  ma7_total_amount_sold  \
# 0                    188.28              3.925              18.000000
# 1                    258.78             14.380               6.000000
# 2                    163.08              4.530              12.000000
# 3                    305.76              4.250              24.000000
# 4                    149.30              4.980              10.000000
# ...                     ...                ...                    ...
# 1708740               72.00              4.000               7.200000
# 1708741               87.00             14.500               2.000000
# 1708742               30.66              5.110               2.000000
# 1708743              190.08              1.320              33.000000
# 1708744              125.76              1.750              20.857143
#
#          ma7_avg_bottle_price  ma7_total_sale_dollars  ma30_total_amount_sold  \
# 0                   11.765000              188.280000                  18.000
# 1                   43.130000              258.780000                   6.000
# 2                   13.590000              163.080000                  12.000
# 3                   12.740000              305.760000                  24.000
# 4                   14.930000              149.300000                  10.000
# ...                       ...                     ...                     ...
# 1708740             11.026000               74.712000                   7.200
# 1708741             43.500000               87.000000                   2.000
# 1708742             15.330000               30.660000                   2.000
# 1708743              7.647500              184.560000                  33.000
# 1708744              6.947857              125.757143                  19.125
#
#          ma30_avg_bottle_price  ma30_total_sale_dollars
# 0                    11.765000                  188.280
# 1                    43.130000                  258.780
# 2                    13.590000                  163.080
# 3                    12.740000                  305.760
# 4                    14.930000                  149.300
# ...                        ...                      ...
# 1708740              11.026000                   74.712
# 1708741              43.500000                   87.000
# 1708742              15.330000                   30.660
# 1708743               7.647500                  184.560
# 1708744               6.726875                  114.570
#
# [1708745 rows x 14 columns]

# %%
df[["city", "item_name"]].drop_duplicates()
# Out:
#             city                      item_name
# 0         ACKLEY  99 BRAND FRUIT PUNCH PET MINI
# 1         ACKLEY    ABSOLUT SWEDISH VODKA 80PRF
# 2         ACKLEY          ADMIRAL NELSON SPICED
# 3         ACKLEY               BACARDI SUPERIOR
# 4         ACKLEY                   BLACK VELVET
# ...          ...                            ...
# 1696386  ZWINGLE       99 BLUE RASPBERRIES MINI
# 1696389  ZWINGLE          GREY GOOSE GLASS PACK
# 1696391  ZWINGLE               HENNESSY VS MINI
# 1696394  ZWINGLE                PATRON REPOSADO
# 1696395  ZWINGLE          PATRON REPOSADO 200ML
#
# [211819 rows x 2 columns]

# %%
query = f"""
WITH sales_data AS (
    SELECT 
        city,
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold,
        AVG(state_bottle_retail) AS avg_bottle_price,
        SUM(volume_sold_liters) AS total_volume_sold_liters,
        SUM(sale_dollars) AS total_sale_dollars,
        AVG(state_bottle_retail - state_bottle_cost) AS avg_bottle_profit
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales`
    WHERE
        bottles_sold > 0
        AND sale_dollars > 0
        AND city IS NOT NULL
    GROUP BY
        city, date, item_name
    HAVING
        date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
),
filtered_sales AS (
    SELECT
        city,
        date,
        item_name,
        total_amount_sold,
        avg_bottle_price,
        total_volume_sold_liters,
        total_sale_dollars,
        avg_bottle_profit
    FROM
        sales_data
    WHERE
        item_name IN (
            SELECT 
                item_name
            FROM
                sales_data
            GROUP BY
                item_name
            HAVING
                SUM(total_amount_sold) > 100  -- Adjust the threshold as needed
        )
)
SELECT
    city,
    date,
    item_name,
    total_amount_sold,
    avg_bottle_price,
    total_volume_sold_liters,
    total_sale_dollars,
    avg_bottle_profit,
    -- 7-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_sale_dollars,
    -- 30-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_sale_dollars,
    -- 60-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_total_sale_dollars
FROM
    filtered_sales
ORDER BY
    date, city, item_name;
"""

query_job = client.query(query)
df = query_job.to_dataframe()
df
# Out:
# I0000 00:00:1722826969.196311  901739 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#             city        date                      item_name  \
# 0         ACKLEY  2023-01-04  99 BRAND FRUIT PUNCH PET MINI
# 1         ACKLEY  2023-01-04    ABSOLUT SWEDISH VODKA 80PRF
# 2         ACKLEY  2023-01-04          ADMIRAL NELSON SPICED
# 3         ACKLEY  2023-01-04               BACARDI SUPERIOR
# 4         ACKLEY  2023-01-04                   BLACK VELVET
# ...          ...         ...                            ...
# 1696393  ZWINGLE  2023-12-11            PARAMOUNT WHITE RUM
# 1696394  ZWINGLE  2023-12-11                PATRON REPOSADO
# 1696395  ZWINGLE  2023-12-11          PATRON REPOSADO 200ML
# 1696396  ZWINGLE  2023-12-11               SOUTHERN COMFORT
# 1696397  ZWINGLE  2023-12-11              UV BLUE RASPBERRY
#
#          total_amount_sold  avg_bottle_price  total_volume_sold_liters  \
# 0                        1             77.40                      0.05
# 1                        8             14.99                      6.00
# 2                        4              4.49                      1.50
# 3                        4              7.50                      1.50
# 4                       20              6.23                     12.00
# ...                    ...               ...                       ...
# 1696393                  6             12.00                     10.50
# 1696394                  2             43.50                      1.50
# 1696395                  2             15.33                      0.40
# 1696396                 48              3.96                      9.60
# 1696397                 24              5.24                      9.00
#
#          total_sale_dollars  avg_bottle_profit  ma7_total_amount_sold  \
# 0                     77.40              25.80               1.000000
# 1                    119.92               5.00               8.000000
# 2                     17.96               1.50               4.000000
# 3                     30.00               2.50               4.000000
# 4                    131.08               2.08              20.000000
# ...                     ...                ...                    ...
# 1696393               72.00               4.00               7.200000
# 1696394               87.00              14.50               2.000000
# 1696395               30.66               5.11               2.000000
# 1696396              190.08               1.32              33.000000
# 1696397              125.76               1.75              20.857143
#
#          ma7_avg_bottle_price  ma7_total_sale_dollars  ma30_total_amount_sold  \
# 0                   77.400000               77.400000                   1.000
# 1                   14.990000              119.920000                   8.000
# 2                    4.490000               17.960000                   4.000
# 3                    7.500000               30.000000                   4.000
# 4                    6.230000              131.080000                  20.000
# ...                       ...                     ...                     ...
# 1696393             11.026000               74.712000                   7.200
# 1696394             43.500000               87.000000                   2.000
# 1696395             15.330000               30.660000                   2.000
# 1696396              7.647500              184.560000                  33.000
# 1696397              6.947857              125.757143                  19.125
#
#          ma30_avg_bottle_price  ma30_total_sale_dollars
# 0                    77.400000                   77.400
# 1                    14.990000                  119.920
# 2                     4.490000                   17.960
# 3                     7.500000                   30.000
# 4                     6.230000                  131.080
# ...                        ...                      ...
# 1696393              11.026000                   74.712
# 1696394              43.500000                   87.000
# 1696395              15.330000                   30.660
# 1696396               7.647500                  184.560
# 1696397               6.726875                  114.570
#
# [1696398 rows x 14 columns]

# %%
START_DATE = "2021-01-01"
END_DATE = "2024-02-01"

OFFSET_START_DATE = (pd.Timestamp(START_DATE) - pd.DateOffset(days=61)).strftime("%Y-%m-%d")

query = f"""
WITH sales_data AS (
    SELECT 
        city,
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold,
        AVG(state_bottle_retail) AS avg_bottle_price,
        SUM(volume_sold_liters) AS total_volume_sold_liters,
        SUM(sale_dollars) AS total_sale_dollars,
        AVG(state_bottle_retail - state_bottle_cost) AS avg_bottle_profit
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales`
    WHERE
        bottles_sold > 0
        AND sale_dollars > 0
        AND city IS NOT NULL
    GROUP BY
        city, date, item_name
    HAVING
        date >= DATE('{OFFSET_START_DATE}')
),
filtered_sales AS (
    SELECT
        sd.city,
        sd.date,
        sd.item_name,
        sd.total_amount_sold,
        sd.avg_bottle_price,
        sd.total_volume_sold_liters,
        sd.total_sale_dollars,
        sd.avg_bottle_profit
    FROM
        sales_data AS sd
    INNER JOIN
        (
            SELECT
                d2.city,
                d2.item_name
            FROM
                (
                    SELECT
                        sd.city,
                        sd.item_name,
                        EXTRACT(YEAR FROM date) AS year
                    FROM
                        sales_data AS sd
                    WHERE
                        sd.date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
                    GROUP BY
                        year, sd.city, sd.item_name 
                    HAVING
                        SUM(sd.total_amount_sold) > 100  -- Adjust the threshold as needed
                        AND COUNT(DISTINCT sd.date) > 180
                ) AS d2
            GROUP BY
                d2.city, d2.item_name
            HAVING
                COUNT(DISTINCT d2.year) >= 3
                --AND MAX(d2.year) = 2024
        ) AS d3
    ON
        sd.city = d3.city
        AND sd.item_name = d3.item_name
    INNER JOIN
        (
            SELECT
                d4.city,
                d4.item_name,
                MAX(EXTRACT(YEAR FROM date)) AS max_year
            FROM
                sales_data AS d4
            GROUP BY
                d4.city, d4.item_name 
            HAVING
                max_year = 2024
        ) AS d5
    ON
        sd.city = d5.city
        AND sd.item_name = d5.item_name
)
SELECT
    city,
    date,
    item_name,
    total_amount_sold,
    avg_bottle_price,
    total_volume_sold_liters,
    total_sale_dollars,
    avg_bottle_profit,
    -- 7-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 6 PRECEDING AND CURRENT ROW) AS ma7_total_sale_dollars,
    -- 30-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 29 PRECEDING AND CURRENT ROW) AS ma30_total_sale_dollars,
    -- 60-day moving averages
    AVG(total_amount_sold) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_total_amount_sold,
    AVG(avg_bottle_price) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_avg_bottle_price,
    AVG(total_sale_dollars) OVER (PARTITION BY city, item_name ORDER BY date ROWS BETWEEN 59 PRECEDING AND CURRENT ROW) AS ma60_total_sale_dollars
FROM
    filtered_sales
WHERE
    date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
ORDER BY
    city, item_name, date;
"""
query_job = client.query(query)
df = query_job.to_dataframe()
df
# Out:
# I0000 00:00:1722836851.011240  901739 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#                   city        date             item_name  total_amount_sold  \
# 0         CEDAR RAPIDS  2021-01-04      BACARDI SUPERIOR                 82
# 1         CEDAR RAPIDS  2021-01-06      BACARDI SUPERIOR                 43
# 2         CEDAR RAPIDS  2021-01-07      BACARDI SUPERIOR                 52
# 3         CEDAR RAPIDS  2021-01-11      BACARDI SUPERIOR                 55
# 4         CEDAR RAPIDS  2021-01-13      BACARDI SUPERIOR                 61
# ...                ...         ...                   ...                ...
# 42923  WEST DES MOINES  2024-01-26  TITOS HANDMADE VODKA                 37
# 42924  WEST DES MOINES  2024-01-29  TITOS HANDMADE VODKA                441
# 42925  WEST DES MOINES  2024-01-30  TITOS HANDMADE VODKA                 42
# 42926  WEST DES MOINES  2024-01-31  TITOS HANDMADE VODKA                200
# 42927  WEST DES MOINES  2024-02-01  TITOS HANDMADE VODKA                 95
#
#        avg_bottle_price  total_volume_sold_liters  total_sale_dollars  \
# 0             10.980000                     48.00              812.94
# 1             10.035000                     35.62              537.93
# 2             12.815000                     47.25              693.18
# 3             11.066250                     42.75              651.63
# 4             10.625000                     38.62              596.25
# ...                 ...                       ...                 ...
# 42923         19.148333                     35.75              654.08
# 42924         18.088276                    423.05             7751.42
# 42925         21.750000                     37.50              711.00
# 42926         14.578750                    161.30             3092.60
# 42927         10.748889                     43.25              926.84
#
#        avg_bottle_profit  ma7_total_amount_sold  ma7_avg_bottle_price  \
# 0               3.660000              82.000000             10.980000
# 1               3.345000              62.500000             10.507500
# 2               4.271667              59.000000             11.276667
# 3               3.688750              58.000000             11.224063
# 4               3.541667              58.600000             11.104250
# ...                  ...                    ...                   ...
# 42923           6.383333             125.428571             17.743169
# 42924           6.030000             169.000000             17.838955
# 42925           7.250000             172.428571             19.130383
# 42926           4.860000             167.857143             18.802004
# 42927           3.584444             145.428571             17.230416
#
#        ma7_total_sale_dollars  ma30_total_amount_sold  ma30_avg_bottle_price  \
# 0                  812.940000               82.000000              10.980000
# 1                  675.435000               62.500000              10.507500
# 2                  681.350000               59.000000              11.276667
# 3                  673.920000               58.000000              11.224063
# 4                  658.386000               58.600000              11.104250
# ...                       ...                     ...                    ...
# 42923             2578.807143              184.966667              17.960122
# 42924             3278.490000              180.200000              18.027031
# 42925             3343.452857              172.000000              18.027031
# 42926             3249.274286              173.466667              17.958739
# 42927             2378.822857              173.033333              17.845480
#
#        ma30_total_sale_dollars  ma60_total_amount_sold  ma60_avg_bottle_price  \
# 0                   812.940000               82.000000              10.980000
# 1                   675.435000               62.500000              10.507500
# 2                   681.350000               59.000000              11.276667
# 3                   673.920000               58.000000              11.224063
# 4                   658.386000               58.600000              11.104250
# ...                        ...                     ...                    ...
# 42923              3436.731333              217.216667              17.722297
# 42924              3428.913667              224.366667              17.694435
# 42925              3200.613667              224.666667              17.864185
# 42926              3226.804333              214.766667              17.842416
# 42927              3210.966333              214.650000              17.726703
#
#        ma60_total_sale_dollars
# 0                   812.940000
# 1                   675.435000
# 2                   681.350000
# 3                   673.920000
# 4                   658.386000
# ...                        ...
# 42923              4205.232167
# 42924              4330.470500
# 42925              4337.694500
# 42926              4117.912833
# 42927              4103.280167
#
# [42928 rows x 17 columns]

# %%
df["date"] = pd.to_datetime(df["date"])
df["year"] = df["date"].dt.year
df.groupby(["city", "item_name"], as_index=True).agg({"year": ["unique", "nunique", "max", "min"]}).sort_values(("year", "nunique"))
# Out:
#                                                                          year  \
#                                                                        unique
# city            item_name
# CEDAR RAPIDS    BACARDI SUPERIOR                     [2021, 2022, 2023, 2024]
# DES MOINES      GREY GOOSE                           [2021, 2022, 2023, 2024]
#                 HAWKEYE VODKA                        [2021, 2022, 2023, 2024]
#                 JACK DANIELS OLD #7 BLACK LABEL      [2021, 2022, 2023, 2024]
# ICE HOLE BUTTERSCOTCH SCHNAPPS
# ICE HOLE CHERRY SCHNAPPS
# ICE HOLE MINT SCHNAPPS
# ICE HOLE PLUM SCHNAPPS
# IL TRAMONTO LIMONCELLO
# ILEGAL MEZCAL JOVEN
# ILEGAL MEZCAL REPOSADO
# IMMORTAL CLAN
# INDOGGO STRAWBERRY GIN
# INFUSED TEQUILA JALAPENO LIME
# INFUSED TEQUILA PINK LEMONADE
# INGENIOZ
# IOWA COFFEE COMPANY LIQUEUR
# IOWA DISTILLING COMPANY STRAIGHT BOURBON WHISKEY
# IOWA LEGENDARY RYE BLACK LABEL
# IOWA LEGENDARY RYE RED LABEL
# IOWA LEGENDARY RYE WHITE LABEL
# IOWA STATE 1858 VODKA
# IOWISH CREAM AMARETTO
# IOWISH CREAM EGG NOG
# IOWISH CREAM LIQUEUR
# IOWISH CREAM SALTED CARAMEL
# IOWISH WHISKEY
# ISAAC BOWMAN PORT FINISH BOURBON
# ISLE OF JURA 10YR
# ITALICUS ROSOLINO
# J & B RARE SCOTCH
# J. RIEGER & CO. CAFFE AMARO
# J. W. DANT 100 PRF BOND BOURBON
# JACK DANIELS 1938 TRIPLE MASH 100PRF
# JACK DANIELS BONDED 100PRF DOM
# JACK DANIELS BONDED RYE 100PF
# JACK DANIELS OLD #7 BLACK LABEL
# JACK DANIELS OLD #7 BLACK LABEL FLAT
# JACK DANIELS OLD #7 BLACK LABEL MINI
# JACK DANIELS OLD #7 BLACK LABEL SQUARE
# JACK DANIELS SINATRA
# JACK DANIELS SINGLE BARREL
# JACK DANIELS SINGLE BARREL BARREL PROOF
# JACK DANIELS SINGLE BARREL PERSONAL COLLECTION
# JACK DANIELS SINGLE BARREL RYE BUY THE BARREL
# JACK DANIELS SINGLE BARREL W/SNIFTER GLASS
# JACK DANIELS TENNESSEE APPLE
# JACK DANIELS TENNESSEE APPLE MINI
# JACK DANIELS TENNESSEE FIRE
# JACK DANIELS TENNESSEE FIRE MINI
# JACK DANIELS TENNESSEE HONEY
# JACK DANIELS TENNESSEE HONEY MINI
# JACK DANIELS TENNESSEE RYE
# JACK DANIELS WINTER JACK
# JACOBS PARDON SMALL BATCH WHISKEY #3
# JAGERMEISTER ALUMINUM SHOT CUP VAP
# JAGERMEISTER LIQUEUR
# JAGERMEISTER LIQUEUR MINI
# JAGERMEISTER LIQUEUR MINI MEISTERS
# JAGERMEISTER MINIMEISTER ICE BUCKET VAP
# JAGERMEISTER MINIMEISTER W/ICE BUCKET
# JAGERMEISTER W/ALUMINUM SHOT CUP
# JAJA BLANCO
# JAMES E PEPPER 1776 STRAIGHT BOURBON WHISKEY 100PRF
# JAMES E PEPPER 1776 STRAIGHT RYE WHISKEY 100PRF
# JAMESON
# JAMESON 18YR
# JAMESON BLACK BARREL
# JAMESON BLACK BARREL W/2 GLASSES
# JAMESON CASKMATES IPA
# JAMESON CASKMATES STOUT
# JAMESON COLD BREW
# JAMESON MINI
# JAMESON ORANGE
# JAMESON ORANGE W/ 2 SODA CANS
# WISCONSIN CLUB SPICED RUM
# WISCONSIN CLUB VODKA
# WOODFORD RESERVE
# WOODFORD RESERVE BATCH PROOF
# WOODFORD RESERVE DOUBLE OAKED
# WOODFORD RESERVE HOLIDAY 2023
# WOODFORD RESERVE KENTUCKY DERBY 2022
# WOODFORD RESERVE PERSONAL SELECTION BUY THE BARREL
# WOODFORD RESERVE RYE
# WOODFORD RESERVE STRAIGHT BOURBON
# WOODFORD RESERVE STRAIGHT MALT
# WOODINVILLE PORT FINISHED BOURBON
# WOODINVILLE STRAIGHT BOURBON
# WOODINVILLE STRAIGHT RYE WHISKEY
# WOODSHED RED
# WRITERS TEARS COPPER POT
# WYCH DR DISTILLING VODKA
# XICALA ANEJO MEZCAL
# XICALA JOVEN MEZCAL
# XICARU REPOSADO MEZCAL
# XICARU SILVER MEZCAL
# YELLOW ROSE PREMIUM AMERICAN WHISKEY
# YELLOW SPOT
# YELLOWSTONE AMERICAN SINGLE MALT
# YELLOWSTONE HAND PICKED 102PR BUY THE BARREL
# YELLOWSTONE HAND PICKED 109PR BUY THE BARREL
# YELLOWSTONE HAND PICKED 115PR BUY THE BARREL
# YELLOWSTONE HAND PICKED BARREL PROGRAM - BUY THE BARREL
# YELLOWSTONE LIMITED EDITION 2023
# YELLOWSTONE SELECT
# YELLOWSTONE SPECIAL FINISHES COLLECTION - TOASTED STAVES
# YU
# YUKON JACK
# YUKON JACK PERMA FROST
# ZAYA GRAN RESERVA RUM
# ZAYA RUM COCOBANA
# ZING ZANG BLAZING BLOODY MARY RTS
# ZING ZANG BLOODY MARY RTS

# %%
df["city"].unique()
# Out:
# array(['ACKLEY', 'ADAIR', 'ADEL', 'AFTON', 'AINSWORTH', 'AKRON',
#        'ALBERT CITY', 'ALBIA', 'ALBION', 'ALBURNETT', 'ALDEN', 'ALGONA',
#        'ALLERTON', 'ALLISON', 'ALTA', 'ALTON', 'ALTOONA', 'AMANA', 'AMES',
#        'ANAMOSA', 'ANITA', 'ANKENY', 'ANTHON', 'APLINGTON', 'ARLINGTON',
#        'ARMSTRONG', 'ARNOLDS PARK', 'ATKINS', 'ATLANTIC', 'AUDUBON',
#        'AURELIA', 'AVOCA', 'BALDWIN', 'BANCROFT', 'BATAVIA', 'BAXTER',
#        'BEDFORD', 'BELLE PLAINE', 'BELLEVUE', 'BELMOND', 'BETTENDORF',
#        'BEVINGTON', 'BIRMINGHAM', 'BLAIRSTOWN', 'BLOOMFIELD',
#        'BLUE GRASS', 'BONAPARTE', 'BONDURANT', 'BOONE', 'BOYDEN', 'BRITT',
#        'BROOKLYN', 'BUFFALO', 'BUFFALO CENTER', 'BURLINGTON', 'CALAMUS',
#        'CALMAR', 'CAMANCHE', 'CARLISLE', 'CARROLL', 'CARSON',
#        'CARTER LAKE', 'CASCADE', 'CASEY', 'CEDAR FALLS', 'CEDAR RAPIDS',
#        'CENTER POINT', 'CENTERVILLE', 'CENTRAL CITY', 'CHARITON',
#        'CHARLES CITY', 'CHEROKEE', 'CLARENCE', 'CLARINDA', 'CLARION',
#        'CLARKSVILLE', 'CLEAR LAKE', 'CLEARLAKE', 'CLERMONT', 'CLINTON',
#        'CLIVE', 'COGGON', 'COLESBURG', 'COLFAX', 'COLO',
#        'COLUMBUS JUNCTION', 'CONRAD', 'COON RAPIDS', 'CORALVILLE',
#        'CORNING', 'CORRECTIONVILLE', 'CORWITH', 'CORYDON',
#        'COUNCIL BLUFFS', 'CRESCENT', 'CRESCO', 'CRESTON', 'CUMMING',
#        'DAKOTA CITY', 'DALLAS CENTER', 'DANVILLE', 'DAVENPORT', 'DAYTON',
#        'DE SOTO', 'DECORAH', 'DELAWARE', 'DELHI', 'DELMAR', 'DENISON',
#        'DENMARK', 'DENVER', 'DES MOINES', 'DEWITT', 'DEXTER',
#        'DONNELLSON', 'DOON', 'DOUDS', 'DOWS', 'DUBUQUE', 'DUMONT',
#        'DUNCOMBE', 'DUNLAP', 'DURANT', 'DYERSVILLE', 'DYSART',
#        'EAGLE GROVE', 'EARLHAM', 'EARLING', 'EARLY', 'EDDYVILLE',
#        'EDGEWOOD', 'ELDON', 'ELDORA', 'ELDRIDGE', 'ELK RUN HEIGHTS',
#        'ELKADER', 'ELLSWORTH', 'ELMA', 'ELY', 'EMMETSBURG', 'ESSEX',
#        'ESTHERVILLE', 'EVANSDALE', 'EXIRA', 'FAIRBANK', 'FAIRFAX',
#        'FAIRFIELD', 'FARLEY', 'FARMINGTON', 'FAYETTE', 'FLOYD', 'FONDA',
#        'FONTANELLE', 'FOREST CITY', 'FORT ATKINSON', 'FORT DODGE',
#        'FORT MADISON', 'FREDERICKSBURG', 'FREMONT', 'GARNAVILLO',
#        'GARNER', 'GARWIN', 'GEORGE', 'GILBERTVILLE', 'GILMAN',
#        'GILMORE CITY', 'GLADBROOK', 'GLENWOOD', 'GLIDDEN', 'GOLDFIELD',
#        'GOWRIE', 'GRAETTINGER', 'GRAND JUNCTION', 'GRAND MOUNDS',
#        'GRANGER', 'GREENE', 'GREENFIELD', 'GRIMES', 'GRINNELL',
#        'GRISWOLD', 'GRUNDY CENTER', 'GUTHRIE CENTER', 'GUTTENBERG',
#        'HAMBURG', 'HAMPTON', 'HARLAN', 'HARPERS FERRY', 'HARTLEY',
#        'HAWARDEN', 'HAZLETON', 'HIAWATHA', 'HILLS', 'HINTON', 'HOLSTEIN',
#        'HOSPERS', 'HOUGHTON', 'HUBBARD', 'HUDSON', 'HUMBOLDT', 'HUMESTON',
#        'HUXLEY', 'IDA GROVE', 'INDEPENDENCE', 'INDIANOLA', 'INWOOD',
#        'IOWA CITY', 'IOWA FALLS', 'JEFFERSON', 'JESUP', 'JEWELL',
#        'JOHNSTON', 'KALONA', 'KANAWHA', 'KELLOGG', 'KEOKUK', 'KEOSAUQUA',
#        'KEOTA', 'KEYSTONE', 'KINGSLEY', 'KNOXVILLE', 'LA PORTE CITY',
#        'LAKE CITY', 'LAKE MILLS', 'LAKE PARK', 'LAKE VIEW', 'LAMONI',
#        'LAMONT', 'LANSING', 'LARCHWOOD', 'LATIMER', 'LAURENS', 'LAWLER',
#        'LE CLAIRE', 'LE GRAND', 'LE MARS', 'LECLAIRE', 'LENOX', 'LEON',
#        'LETTS', 'LIME SPRINGS', 'LISBON', 'LIVERMORE', 'LOGAN',
#        'LOHRVILLE', 'LONE TREE', 'LOST NATION', 'LOVILIA', 'LUXEMBURG',
#        'MADRID', 'MALCOM', 'MALVERN', 'MANCHESTER', 'MANLY', 'MANNING',
#        'MANSON', 'MAPLETON', 'MAQUOKETA', 'MARCUS', 'MARENGO', 'MARION',
#        'MARQUETTE', 'MARSHALLTOWN', 'MARTELLE', 'MARTENSDALE',
#        'MASON CITY', 'MAYNARD', 'MECHANICSVILLE', 'MEDIAPOLIS',
#        'MELBOURNE', 'MELCHER-DALLAS', 'MERRILL', 'MIDDLETOWN', 'MILFORD',
#        'MILO', 'MILTON', 'MINDEN', 'MISSOURI VALLEY', 'MITCHELLVILLE',
#        'MONONA', 'MONROE', 'MONTEZUMA', 'MONTICELLO', 'MONTROSE',
#        'MORAVIA', 'MORNING SUN', 'MOUNT AYR', 'MOUNT PLEASANT',
#        'MOUNT VERNON', 'MOVILLE', 'MT PLEASANT', 'MURRAY', 'MUSCATINE',
#        'NASHUA', 'NEOLA', 'NEVADA', 'NEW HAMPTON', 'NEW HARTFORD',
#        'NEW LONDON', 'NEW SHARON', 'NEW VIRGINIA', 'NEWTON', 'NICHOLS',
#        'NORA SPRINGS', 'NORTH ENGLISH', 'NORTH LIBERTY', 'NORTHWOOD',
#        'NORWALK', 'NORWAY', 'OAKLAND', 'ODEBOLT', 'OELWEIN', 'OGDEN',
#        'OKOBOJI', 'OLIN', 'ONAWA', 'ORANGE CITY', 'OSAGE', 'OSCEOLA',
#        'OSKALOOSA', 'OSSIAN', 'OTHO', 'OTTUMWA', 'OXFORD',
#        'OXFORD JUNCTION', 'PACIFIC JUNCTION', 'PALO', 'PANORA',
#        'PARKERSBURG', 'PAULLINA', 'PELLA', 'PEOSTA', 'PERRY',
#        'PLEASANT HILL', 'PLEASANT VALLEY', 'PLEASANTVILLE', 'POCAHONTAS',
#        'POLK CITY', 'POMEROY', 'POSTVILLE', 'PRAIRIE CITY', 'PRESTON',
#        'PRIMGHAR', 'PRINCETON', 'RAYMOND', 'RED OAK', 'REDFIELD',
#        'REINBECK', 'REMSEN', 'RICEVILLE', 'RIDGEWAY', 'RIVERSIDE',
#        'ROBINS', 'ROCK RAPIDS', 'ROCK VALLEY', 'ROCKFORD', 'ROCKWELL',
#        'ROCKWELL CITY', 'ROLAND', 'ROLFE', 'RUNNELLS', 'RUTHVEN',
#        'SAC CITY', 'SAGEVILLE', 'SAINT ANSGAR', 'SALEM', 'SANBORN',
#        'SCRANTON', 'SERGEANT BLUFF', 'SEYMOUR', 'SHEFFIELD', 'SHELBY',
#        'SHELDON', 'SHELLSBURG', 'SHENANDOAH', 'SHUEYVILLE', 'SIBLEY',
#        'SIDNEY', 'SIGOURNEY', 'SIOUX CENTER', 'SIOUX CITY',
#        'SIOUX RAPIDS', 'SLATER', 'SLOAN', 'SOLON', 'SPENCER',
#        'SPIRIT LAKE', 'SPRINGVILLE', 'ST ANSGAR', 'ST CHARLES',
#        'ST LUCAS', 'STANTON', 'STANWOOD', 'STATE CENTER', 'STORM LAKE',
#        'STORY CITY', 'STRATFORD', 'STRAWBERRY POINT', 'STUART', 'SULLY',
#        'SUMNER', 'SUTHERLAND', 'SWEA CITY', 'SWISHER', 'TABOR', 'TAMA',
#        'TEMPLETON', 'TIFFIN', 'TIPTON', 'TOLEDO', 'TRAER', 'TREYNOR',
#        'TRIPOLI', 'TROY MILLS', 'TRURO', 'URBANA', 'URBANDALE',
#        'VAN HORNE', 'VAN METER', 'VICTOR', 'VILLISCA', 'VINTON',
#        'WALCOTT', 'WALFORD', 'WALKER', 'WALL LAKE', 'WALNUT', 'WAPELLO',
#        'WASHBURN', 'WASHINGTON', 'WATERLOO', 'WAUKEE', 'WAUKON',
#        'WAVERLY', 'WEBSTER CITY', 'WELLMAN', 'WELLSBURG', 'WELTON',
#        'WESLEY', 'WEST BEND', 'WEST BRANCH', 'WEST BURLINGTON',
#        'WEST DES MOINES', 'WEST LIBERTY', 'WEST POINT', 'WEST UNION',
#        'WEVER', 'WHAT CHEER', 'WHEATLAND', 'WHITTEMORE', 'WILLIAMS',
#        'WILLIAMSBURG', 'WILTON', 'WINDSOR HEIGHTS', 'WINFIELD',
#        'WINTERSET', 'WINTHROP', 'WOODBINE', 'WOODWARD', 'WYOMING',
#        'ZWINGLE'], dtype=object)

# %%
old_training_data_query = f"""
SELECT 
    city,
    date,
    item_description AS item_name,
    SUM(bottles_sold) AS total_amount_sold,
    AVG(state_bottle_retail) AS avg_bottle_price,
    SUM(volume_sold_liters) AS total_volume_sold_liters,
    SUM(sale_dollars) AS total_sale_dollars,
    AVG(state_bottle_retail - state_bottle_cost) AS avg_bottle_profit
FROM
    `bigquery-public-data.iowa_liquor_sales.sales`
WHERE
    bottles_sold > 0
    AND sale_dollars > 0
GROUP BY
    city, date, item_name
HAVING
    date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
"""
old_training_data_query_job = client.query(old_training_data_query)
old_df = old_training_data_query_job.to_dataframe()
old_df
# Out:
# I0000 00:00:1722826458.926348  901739 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#                  city        date  \
# 0            WATERLOO  2023-03-09
# 1              ANKENY  2023-05-24
# 2           URBANDALE  2023-01-12
# 3          FORT DODGE  2023-08-04
# 4          SIOUX CITY  2023-12-12
# ...               ...         ...
# 1708740    DES MOINES  2023-02-16
# 1708741  CEDAR RAPIDS  2023-09-11
# 1708742      HIAWATHA  2023-04-14
# 1708743     DAVENPORT  2023-03-20
# 1708744      GRINNELL  2023-11-28
#
#                                                  item_name  total_amount_sold  \
# 0                   FIREBALL CINNAMON WHISKEY PARTY BUCKET                  3
# 1                          NEW AMSTERDAM PINK WHITNEY MINI                 13
# 2                 FIREBALL CINNAMON WHISKEY MINI DISPENSER                  9
# 3                                TEQUILA ROSE LIQUEUR MINI                  7
# 4                                 99 BLUE RASPBERRIES MINI                  5
# ...                                                    ...                ...
# 1708740                                   REMY MARTIN VSOP                  2
# 1708741  OLE SMOKY WHITE CHOCOLATE STRAWBERRY MOONSHINE...                  8
# 1708742                                  BLACK VELVET MINI                  8
# 1708743              OLE SMOKY BUTTER PECAN MOONSHINE MINI                  8
# 1708744                OLE SMOKY PEPPERMINT MOONSHINE MINI                  8
#
#          avg_bottle_price  total_volume_sold_liters  total_sale_dollars  \
# 0                   77.40                      0.15              232.20
# 1                    6.92                      0.65               89.96
# 2                   38.70                      0.45              348.30
# 3                    7.05                      0.35               49.35
# 4                   77.40                      0.25              387.00
# ...                   ...                       ...                 ...
# 1708740             11.82                      0.40               23.64
# 1708741             13.13                      0.40              105.04
# 1708742             13.31                      0.40              106.48
# 1708743             13.13                      0.40              105.04
# 1708744             13.13                      0.40              105.04
#
#          avg_bottle_profit
# 0                    25.80
# 1                     2.31
# 2                    12.90
# 3                     2.35
# 4                    25.80
# ...                    ...
# 1708740               3.94
# 1708741               4.38
# 1708742               4.44
# 1708743               4.38
# 1708744               4.38
#
# [1708745 rows x 8 columns]

# %%
training_data_query = f"""
WITH sales_per_day AS (
    SELECT
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales`
    WHERE
        date BETWEEN DATE('{START_DATE}') AND DATE('{END_DATE}')
        AND bottles_sold > 0
    GROUP BY
        date, item_name
),
sales_per_month AS (
    SELECT
        item_name,
        EXTRACT(YEAR FROM date) AS year,
        EXTRACT(MONTH FROM date) AS month,
        COUNT(DISTINCT date) AS days_with_sales
    FROM
        sales_per_day
    GROUP BY
        item_name, year, month
),
qualified_products AS (
    SELECT
        item_name
    FROM
        sales_per_month
    WHERE
        days_with_sales >= 10
    GROUP BY
        item_name, year, month
    HAVING
        COUNT(DISTINCT CONCAT(year, '-', month)) = COUNT(*)
)
SELECT
    date,
    item_name,
    total_amount_sold
FROM
    sales_per_day
WHERE
    item_name IN (SELECT item_name FROM qualified_products)
"""
training_data_query_job = client.query(training_data_query)
df = training_data_query_job.to_dataframe()
df
# Out:
# I0000 00:00:1722632878.925677  412845 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
#               date                               item_name  total_amount_sold
# 0       2023-06-30  FIREBALL CINNAMON WHISKEY PARTY BUCKET                107
# 1       2023-05-30                          99 FRUITS MINI                 76
# 2       2023-05-23            CROWN ROYAL REGAL APPLE MINI                207
# 3       2023-06-30                        CROWN ROYAL MINI                153
# 4       2023-03-30                       BLACK VELVET MINI                 89
# ...            ...                                     ...                ...
# 345921  2023-10-30                      BURNETTS RASPBERRY                 60
# 345922  2023-02-07                     MR BOSTON LIGHT RUM                 60
# 345923  2023-01-03                          DON AGAVE GOLD                 60
# 345924  2023-08-28  ON THE ROCKS COCKTAILS LARIOS AVIATION                 60
# 345925  2023-02-07            MR BOSTON ENGLISH MARKET GIN                 60
#
# [345926 rows x 3 columns]

# %%
qty_of_months = len(pd.date_range(start=pd.to_datetime(START_DATE), end=pd.to_datetime(END_DATE), freq="M"))

# %%
training_data_query = f"""
WITH sales_per_day AS (
    SELECT
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales`
    WHERE
        date BETWEEN DATE('2023-01-01') AND DATE('2024-01-01')
    GROUP BY
        date, item_name
),
sales_per_month AS (
    SELECT
        item_name,
        EXTRACT(YEAR FROM date) AS year,
        EXTRACT(MONTH FROM date) AS month,
        COUNT(DISTINCT date) AS days_with_sales
    FROM
        sales_per_day
    GROUP BY
        item_name, year, month
),
qualified_products AS (
    SELECT
        item_name
    FROM
        sales_per_month
    WHERE
        days_with_sales >= 10
    GROUP BY
        item_name
    HAVING
        COUNT(DISTINCT CONCAT(year, '-', month)) = (
            SELECT COUNT(DISTINCT EXTRACT(YEAR FROM date) || '-' || EXTRACT(MONTH FROM date))
            FROM sales_per_day
        )
)
SELECT
    spd.date,
    spd.item_name,
    SUM(spd.total_amount_sold) AS total_amount_sold
FROM
    sales_per_day spd
JOIN
    qualified_products qp ON spd.item_name = qp.item_name
GROUP BY
    spd.date, spd.item_name
"""
training_data_query_job = client.query(training_data_query)
df = training_data_query_job.to_dataframe()
df
# Out:
# I0000 00:00:1722634533.588629  412845 check_gcp_environment_no_op.cc:29] ALTS: Platforms other than Linux and Windows are not supported
# Empty DataFrame
# Columns: [date, item_name, total_amount_sold]
# Index: []

# %%
df.loc[df["item_name"] == "WESTWARD CASK STRENGTH 125 WHISKEY"]
# Out:
#               date                           item_name  total_amount_sold
# 93855   2023-06-29  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 94046   2023-10-02  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 96655   2023-06-03  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97246   2023-06-16  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97426   2023-10-09  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97978   2023-06-23  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 99798   2023-09-01  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100259  2023-11-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100351  2023-08-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100362  2023-07-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100430  2023-05-18  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100451  2023-06-06  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 101067  2023-10-23  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 101477  2023-09-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 104054  2023-06-14  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 106464  2023-11-06  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 106471  2023-07-26  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 107094  2023-10-16  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 107650  2023-07-24  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 108597  2023-06-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 109886  2023-12-20  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 110227  2023-06-01  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 110365  2023-07-20  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 111644  2023-08-24  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 111811  2023-07-19  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 112306  2023-06-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 112491  2023-06-09  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 113481  2023-10-27  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 114207  2023-06-21  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 114720  2023-07-21  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 115174  2023-05-24  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 118070  2023-05-17  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 119487  2023-05-30  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 121074  2023-05-11  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 125163  2023-05-26  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 127785  2023-05-31  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 130410  2023-11-13  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 140233  2023-05-12  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 145662  2023-12-22  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 151414  2023-05-16  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 156373  2023-05-10  WESTWARD CASK STRENGTH 125 WHISKEY                  4
# 160110  2023-12-27  WESTWARD CASK STRENGTH 125 WHISKEY                  4
# 193704  2023-01-30  WESTWARD CASK STRENGTH 125 WHISKEY                  6

# %%
# item_df = df.loc[(df["item_name"] == "WESTWARD CASK STRENGTH 125 WHISKEY	") & (df["total_amount_sold"] > 0)]
# item_df = df.loc[df["total_amount_sold"] > 0]
item_df = df.copy()

item_df["date"] = pd.to_datetime(item_df["date"])

item_df["year"] = item_df["date"].dt.year
item_df["month"] = item_df["date"].dt.month

item_unique_monthly_days = item_df.groupby(["item_name", "year", "month"], as_index=False)["total_amount_sold"].nunique()
item_unique_monthly_days
# Out:
#                                 item_name  year  month  total_amount_sold
# 0                   10TH MOUNTAIN BOURBON  2023     12                 11
# 1      173 CRAFT DISTILLERY BARREL & KANE  2023     11                 11
# 2      173 CRAFT DISTILLERY BARREL & KANE  2023     12                  6
# 3        173 CRAFT DISTILLERY PREMIUM GIN  2023     11                  9
# 4        173 CRAFT DISTILLERY PREMIUM GIN  2023     12                  4
# ...                                   ...   ...    ...                ...
# 22416           ZING ZANG BLOODY MARY RTS  2023      8                 11
# 22417           ZING ZANG BLOODY MARY RTS  2023      9                 11
# 22418           ZING ZANG BLOODY MARY RTS  2023     10                  8
# 22419           ZING ZANG BLOODY MARY RTS  2023     11                 10
# 22420           ZING ZANG BLOODY MARY RTS  2023     12                 13
#
# [22421 rows x 4 columns]

# %%
df.loc[df["item_name"] == "WESTWARD CASK STRENGTH 125 WHISKEY"]
# Out:
#               date                           item_name  total_amount_sold
# 93855   2023-06-29  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 94046   2023-10-02  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 96655   2023-06-03  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97246   2023-06-16  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97426   2023-10-09  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 97978   2023-06-23  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 99798   2023-09-01  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100259  2023-11-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100351  2023-08-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100362  2023-07-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100430  2023-05-18  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 100451  2023-06-06  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 101067  2023-10-23  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 101477  2023-09-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 104054  2023-06-14  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 106464  2023-11-06  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 106471  2023-07-26  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 107094  2023-10-16  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 107650  2023-07-24  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 108597  2023-06-07  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 109886  2023-12-20  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 110227  2023-06-01  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 110365  2023-07-20  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 111644  2023-08-24  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 111811  2023-07-19  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 112306  2023-06-22  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 112491  2023-06-09  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 113481  2023-10-27  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 114207  2023-06-21  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 114720  2023-07-21  WESTWARD CASK STRENGTH 125 WHISKEY                  1
# 115174  2023-05-24  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 118070  2023-05-17  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 119487  2023-05-30  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 121074  2023-05-11  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 125163  2023-05-26  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 127785  2023-05-31  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 130410  2023-11-13  WESTWARD CASK STRENGTH 125 WHISKEY                  2
# 140233  2023-05-12  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 145662  2023-12-22  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 151414  2023-05-16  WESTWARD CASK STRENGTH 125 WHISKEY                  3
# 156373  2023-05-10  WESTWARD CASK STRENGTH 125 WHISKEY                  4
# 160110  2023-12-27  WESTWARD CASK STRENGTH 125 WHISKEY                  4
# 193704  2023-01-30  WESTWARD CASK STRENGTH 125 WHISKEY                  6

# %%
item_unique_monthly_days.sort_values("total_amount_sold")
# Out:
#                                    item_name  year  month  total_amount_sold
# 21771     WESTWARD CASK STRENGTH 125 WHISKEY  2023      6                  1
# 17724        SHANKYS WHIP BLACK SPIRITS MINI  2023      1                  1
# 10836                          JIM BEAM MINI  2024      1                  1
# 17600            SEAGRAMS EXTRA DRY GIN MINI  2023      3                  1
# 6466                    DEKUYPER BUTTERSHOTS  2024      1                  1
# ...                                      ...   ...    ...                ...
# 9552                             HENNESSY VS  2023     11                 29
# 395                               99 BANANAS  2023     11                 29
# 8267   FIREBALL CINNAMON WHISKEY MINI SLEEVE  2023     11                 29
# 12926                  MCCORMICK 80PRF VODKA  2023     11                 29
# 5876                       CROWN ROYAL PEACH  2023     11                 29
#
# [22421 rows x 4 columns]

# %%
old_unique_item_counts = old_df["item_name"].nunique()
unique_item_counts = df["item_name"].nunique()

print(
    f"Previous dataset unique items count: \033[1;31m{old_unique_item_counts:,}\033[0m | New dataset unique items count: \033[1;32m{unique_item_counts:,}\033[0m",
    f"Difference: \033[1;31m{old_unique_item_counts - unique_item_counts:,}\033[0m",
    f"Percentage reduction: \033[1;31m{(old_unique_item_counts - unique_item_counts)/old_unique_item_counts:.2%}\033[0m",
    sep="\n",
)
# Out:
# Previous dataset unique items count: 4,552 | New dataset unique items count: 2,276
# Difference: 2,276
# Percentage reduction: 50.00%

# %%
training_data_table_creation_query = """
CREATE OR REPLACE VIEW bqmlforecast.training_data AS
(
    SELECT 
        date,
        item_description AS item_name,
        SUM(bottles_sold) AS total_amount_sold
    FROM
        `bigquery-public-data.iowa_liquor_sales.sales` 
    GROUP BY
        date, item_name
    HAVING 
        date BETWEEN DATE('2023-01-01') AND DATE('2024-01-01')
)
"""
training_data_table_creation_job = client.query(training_data_table_creation_query)

# %%
create_model_query = """
CREATE OR REPLACE MODEL bqmlforecast.arima_model

OPTIONS(
  MODEL_TYPE='ARIMA',
  TIME_SERIES_TIMESTAMP_COL='date', 
  TIME_SERIES_DATA_COL='total_amount_sold',
  TIME_SERIES_ID_COL='item_name',
  HOLIDAY_REGION='US'
) AS

SELECT 
    date,
    item_name,
    total_amount_sold
FROM
  bqmlforecast.training_data
"""
create_model_job = client.query(create_model_query)

# %%
evaluate_query = """
SELECT
  *
FROM
  ML.EVALUATE(MODEL bqmlforecast.arima_model)
"""
